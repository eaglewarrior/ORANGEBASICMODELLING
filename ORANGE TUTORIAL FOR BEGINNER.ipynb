# %% [markdown]
# # Data Analysis Using Orange

# %% [markdown]
# *Data is incredibly important for businesses because it helps them to expose variability and optimize their operations, especially for decision making.As the growth of data is increasing exponentially with time, due to which need of data scientist is increasing too.But writing code every time would be tedious & time-consuming this gave rise to demand for GUI based tools & orange comes into picture.*

# %% [markdown]
# *I will introduce you to another GUI based tool – Orange. This tool is great for beginners who want to visualize patterns and understand their data without really knowing how to code.*

# %% [markdown]
# *We will cover the following topics in this tutorial*<br>
# - ORANGE's history, its transition to python and set up of orange
#
# - A tutorial for beginners to use orange which will include playing with dataset and understanding it plus visualizing it
#
# - We will train a linear model for basic understanding
#
# - Lastly will discuss how modern-day energy consumption problem can be regulated using smart meter Data analysis.<br><br><br>
# *I assure if you follow this tutorial along, you can build your own model and make a prediction by using datasets of your choice.But first, let us know little bit about orange.*

# %% [markdown]
# ### Why Orange?

# %% [markdown]
# - There is no need of programming
# - Data is present visually
# - Multititude of Machine learning
# - Allows classification and Clustering
# - It is  free

# %% [markdown]
# ### Orange's History

# %% [markdown]
# - *The development was started on 1997 by Janez Demšar & Blaž Zupan.Development continued at the Artificial Intelligence Laboratory, University of Ljubljana and is currently undertaken at Laboratory of Bioinformatics, University of Ljubljana*
# - *Conceived as a C++ library*

# %% [markdown]
# ## Orange – Transition to Python

# %% [markdown]
# - *On 1999 Orange was migrated and used exclusively as a Python module.*
# - *Clean and simple syntax that is easy to learn and understand, enabled wider adoption and collaboration*
# - *Migration to Python also simplified the development of a graphical user interface*

# %% [markdown]
# ## Orange - Today

# %% [markdown]
# - *Open-source (GPL license) framework that features both scripting and visual programming*
# - *Provides data visualization and data analysis for novice and expert, through interactive workflows & possibility to use it programmatically via GUI (Orange canvas, PyQt).*

# %% [markdown]
# ![1.JPG](attachment:1.JPG)

# %% [markdown]
# ## How to set up orange???

# %% [markdown]
# *You need to have python3 or python 2.7 installed on your machine, both python2.7 and python3 compatible version for orange is available but python3 is most recommended as latest development is on python3 *
# - *Download orange from https://orange.biolab.si/download/ available for windows, mac, and Linux.*
# - *You can install orange by writing "pip install orange3" in command prompt make sure python is added in path variable *
# - *I recommend to use  Anaconda distribution and Add conda-forge to the list of channels you can install packages from "conda config --add channels conda-forge" and run "conda install orange3"*

# %% [markdown]
# *Now you are ready to build our first basic linear model in orange.So let's get started.*

# %% [markdown]
# # Beginners Tutorial

# %% [markdown]
# ### STEP 1:Importing our data<br>
# *Click on the “Data” tab on the widget selector menu and drag the widget “File” to our blank workflow.*

# %% [markdown]
# ![2.png](attachment:2.png)

# %% [markdown]
# ## Step 2: <br>
# *Double click the “File” widget and select the file you want to load into the workflow.You can see the browse documentation dataset option .You can use anyone one you want,in this tutorial we will use zoo.tab dataset.*

# %% [markdown]
# ## Step 3:<br>
# *Click on the dotted line encircling the “File” widget and drag, and then click anywhere in the blank space.As we need a data table to better visualize our findings, we click on the “Data Table” widget.*

# %% [markdown]
# ![3.png](attachment:3.png)

# %% [markdown]
# *Now double click the widget to visualize your table.*<br>
# ![5.JPG](attachment:5.JPG)
# *And you will see something like this*

# %% [markdown]
# ## Step 4:<br>
# *Click on the dotted line encircling the “File” widget and drag, and then click anywhere in the blank space like we did before and search for data sampler*
# ![12.JPG](attachment:12.JPG)
# *Whenever we have to build prediction model we have to connect them to naive bayes or classification tree*

# %% [markdown]
# ## Step 5:<br>
# *So now we will Click on the dotted line encircling the “Data Sampler” widget and drag, and then click anywhere in the blank space like we did before and search for naive bayes,after selecting naives bayes it you will get a pop up like this just click ok*
# ![pop.JPG](attachment:pop.JPG)
# *and you will get something like this*
# ![nai.JPG](attachment:nai.JPG)

# %% [markdown]
# *Do similar for classification tree we will something like this.*
# ![claassification.JPG](attachment:claassification.JPG)

# %% [markdown]
# ## Step 6:
# *So now we will Click on the dotted line encircling the “Data Sampler” widget and drag, and then click anywhere in the blank space like we did before and search for Predictions ,after selecting it you will get a pop up.So just click on clear all*
# ![clearall.JPG](attachment:clearall.JPG)

# %% [markdown]
# *then just click on middle of the box of the Remaining Data and connect it to middile of box of the Data ,ensure it is connected to centre of blocks as sometimes you will miss the green arrow.*
# ![clee.JPG](attachment:clee.JPG)
# *And you will get something like this*
# ![preee.JPG](attachment:preee.JPG)

# %% [markdown]
# ## Step 7:
# *So now we will click on the dotted line encircling the “Naive Bayes” widget and drag, and then click anywhere in the blank space.And search for Nomogram.*
# ![33.JPG](attachment:33.JPG)
# *Just double click on nomogram and change few attributes as shown in below image,we can draw the points to see changes in probability*
# ![nomo.JPG](attachment:nomo.JPG)

# %% [markdown]
# ## Step 8:
# * Just click on the dotted line of naive bayes and connect it to prediction model and click on the dotted line of classification model and connect it to prediction model*
# ![three.JPG](attachment:three.JPG)

# %% [markdown]
# *Double click on Predictions and you will see how it come up with answers like they now can tell that bear is a mammal as they are looking at 16 of data  attributes*
# ![bear.JPG](attachment:bear.JPG)

# %% [markdown]
# ## Step 8 A:(OPTIONAL STEP)
# *Now we can visualize tha data by connecting the file widget to any of the widget of the visualize Tab.Like here i have used two widget,namely **attribute statistics** and **distribution**,just drag and drop this two widget and connect it to the file widget as shown in image*
# ![visullll.JPG](attachment:visullll.JPG)
# *1)Double click on **attribute statistics** a window will appear as shown in image below where 0 means no and 1 means yes,it shows how many animal has hair and how many does not have hair.
# ![ATT.JPG](attachment:ATT.JPG)
# 2)Double click on **Distribution** and a window will appear which shows ambhibian in target and it is in zero means no hair for ambhibian in the graph
# you can change the target and see the results*
# ![anbhiiii.JPG](attachment:anbhiiii.JPG)

# %% [markdown]
# ## Step 9:
# *Go to prediction and in the show predicted probabilites tab select amphibian <br>Then click on dotted lines of predictions and search for Select attributes.*
# ![nowww.JPG](attachment:nowww.JPG)
# *Then double click on it and window will appear the follow the steps as seen in the image*

# %% [markdown]
# ![sa1.JPG](attachment:sa1.JPG)
# *Select the attribute shown in figure and click on the arrow point to left*
# ![sa2.JPG](attachment:sa2.JPG)
# *then select those attribute we transferred to left and click the button pointing towards right and click on apply*
# ![saa3.JPG](attachment:saa3.JPG)
# *And you will get something like this*
# ![sA4.JPG](attachment:sA4.JPG)
# *Now we come to visualization where we will click on the dotted line of select attributes and search for scatter plot *
# ![hee.JPG](attachment:hee.JPG)
# *And double click on it to see the results.*
# ![finalllllllllllll.JPG](attachment:finalllllllllllll.JPG)
# *Here if we zoom in the graph by selecting the area of graph,we can draw the conclusion after visulaton of data point which are insights we can conclude that naive bayes is more accurate then classification tree.You can see that by taking the cursor on the points of graph *
# ![saregamam.JPG](attachment:saregamam.JPG)

# %% [markdown]
# ## Step 10:Training our model
# *For this you can go to file widget double click on it and select any variable column from it and select it as the target variable. Click Apply<br>Once we have set our target variable, find the clean data from the “Impute” widget as follows and place the “Logistic Regression” widget.*
# ![tr1.png](attachment:tr1.png)
# *Next, click on the “Impute” or the “Logistic Regression” widget and find the “Test and Score” widget. Make sure you connect both the data and the model to the testing widget.*
# ![tr2.png](attachment:tr2.png)
# *Now, click on the “Test and Score” widget to see how well your model is doing.*
# ![tr3.JPG](attachment:tr3.JPG)
# *To visualize the results better, drag and drop from the “Test and Score” widget to fin d “Confusion Matrix”.*
# ![tr7.png](attachment:tr7.png)
# *Once you’ve placed it,Double click on it to visualize*
# ![confusion.JPG](attachment:confusion.JPG)
# *This way, you can test out different models and see how accurately they perform*

# %% [markdown]
# *Now we have came to end of the tutorial we are in our last step of how we can use data analysis or data visulaization for solving real world problem*

# %% [markdown]
# ## Smart Meter Data Analytics using Orange
# ##### PRESENT SCENARIO
# - By 2040, world energy consumption will grow by 57%.
# - Coal, oil and gas form 80% of the world energy supply and their sources are depleting rapidly.<br>
# *I came across this topic in Scipy 2017 india where speakers Ankit Mahato & Ashita Prasad spoke about this*
# ### How can we solve this problem by using Smart meters <br><br>
# - Smart meter records the energy consumed at every 15-minute interval allowing quantitative measurement, calibration and control, communication and power management
# - Recorded data is communicated back to the data warehouse and it is used for analysis of energy consumption patterns and future demand prediction
# - Smart meter analytics help customers in better understanding their energy usage patterns and obtain personalized feedback and incentives to save energy and money

# %% [markdown]
# #### Growing volume of sensor data
# - Growing usage of smart meters leads to thegeneration of large volume of sensor data which can be analyzed to identify the various energy consumption patterns useful for managing the smart grid.

# %% [markdown]
# #### Benefit of Analytics
# - Identified consumer clusters enable the utility companies in preparing segment specific campaigns and tariffs to distribute
#  the peak energy loads. This also helps them in meeting the electricity supply-demand more efficiently, thereby limiting energy loss and preventing grid over-load in future.
